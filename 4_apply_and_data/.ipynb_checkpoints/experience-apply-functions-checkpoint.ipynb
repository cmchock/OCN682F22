# %%
# Write you library imports here. E.g.:
# library(ggplot2 )
# ...
library(ggplot2)
library(tidyverse)

# %% [markdown]
# ### Instructions:
#
# 1. it is considered proper programming practice to load all the libraries you need in the first cell of a notebook or at the top of the R-Markdown file. Put all your imports (e.g., `library(ggplot)`) in the cell above.
# 2. Create as many cells as needed to answer a question
#   * Group code that is logically related in the same cell
#   * Keep cells relatively small
#   * Format long statements or expressions, including `ggplot`, across multiple lines
# 3. Submit your work to GitHub under your MBIO repository.
#   * Folder should be called `4_apply_and_data`

# %% [markdown]
# ### Q1
#
# * Write a function called `sd_x` that computes the standard deviation from first principles. Recall that the standard deviation is computed as
#
# $$
# \sigma = \sqrt{\frac{\sum{(x_i - \mu)^2}}{N-1}}
# $$
#
# * $\mu$ is simply the mean of the vector of inputs
#   * it can be computed using the `mean` function
#
#
# For example, given:
#
# ```x = c(1,2,3)```
#
# Since $\mu = 2$, then $\sigma = \sqrt{\frac{(1-2)^2 + (2-2)^2 + (3-2)^2}{3}} = 1$.

# %%
# Write your code here
# use extra cells if needed
x <- c(1,2,3)
sd_x = sd(x)
sd_x
# Out:
# [1] 1

# %% [markdown]
# ### Optional Question
#
# Remember that we cannot compute the standard deviation of a single value. As such, modify your `sd_x` code to throw an error similar to those R generates when your code contains an error, whenever a user calls `sd_x` with a list containing a single element. Various methods can be used to accomplish this. One such way is by using the [`assertthat` package](https://github.com/hadley/assertthat)

# %%
# Write your code here if you choose to answer the question above
# use extra cells if needed

# %% [markdown]
# ### Q2
# Given the following matrix of data where each column consists of a variable:
# 1. Convert this data frame into a tibble called data_tbl
# 2. Use one of the apply-type of functions in conjunction with `sd_x` you wrote previously to compute the standard deviation for each column.

# %%
data = matrix(1:50, ncol=5)
colnames(data) = c("variable_1", "variable_2", "variable_3", "variable_4", "variable_5")
data
# Out:
#       variable_1 variable_2 variable_3 variable_4 variable_5
#  [1,]  1         11         21         31         41
#  [2,]  2         12         22         32         42
#  [3,]  3         13         23         33         43
#  [4,]  4         14         24         34         44
#  [5,]  5         15         25         35         45
#  [6,]  6         16         26         36         46
#  [7,]  7         17         27         37         47
#  [8,]  8         18         28         38         48
#  [9,]  9         19         29         39         49
# [10,] 10         20         30         40         50

# %%
# Write your code here
# use extra cells if needed
data_tbl = data
as_tibble(data_tbl)
# Out:
#    variable_1 variable_2 variable_3 variable_4 variable_5
# 1   1         11         21         31         41
# 2   2         12         22         32         42
# 3   3         13         23         33         43
# 4   4         14         24         34         44
# 5   5         15         25         35         45
# 6   6         16         26         36         46
# 7   7         17         27         37         47
# 8   8         18         28         38         48
# 9   9         19         29         39         49
# 10 10         20         30         40         50

# %%
apply(data_tbl,2,sd)
# Out:
# variable_1 variable_2 variable_3 variable_4 variable_5
#    3.02765    3.02765    3.02765    3.02765    3.02765

# %% [markdown]
# ### Q3
#
# * In this question, we will build a simulated dataset for healthy and diseased corals.  You will be creating a `tibble` called `coral_health_tbl` that contains 2 columns:
#
# 1. A column called `coral`. Generate this column by sampling 100 coral species from the following values
# ```
# coral_pop = c("Montipora capitata",
#   "Porites compressa",
#   "Porites lobata")
# ```
#  * You can use the function `sample` to select 100 values from the vector `coral_pop`
#    * You can see how the function sample works [here](https://www.rdocumentation.org/packages/base/versions/3.6.2/topics/sample)
#
# 2. The second column is called `is_diseased`.
#     * it represents 100 randomly selected `TRUE` or `FALSE` values that represent whether the coral is healthy or diseased.
#     * Healthy corals (`is_diseased == FALSE`; not diseased) occur with a probability of 0.8, i.e. (`is_diseased == TRUE`) occurs with a probability of 0.2

# %%
# Write your code here
# use extra cells if needed
coral_pop = c("Montipora capitata",
"Porites compressa",
"Porites lobata")
coral_health = c("is_healthy", "is_diseased")

# %%
coral_health_tbl <-data.frame(
    coral = sample(coral_pop,size = 100, replace = TRUE),
    is_diseased = sample(coral_health, size = 100, replace = TRUE, prob = c(0.8, rep(0.1, 1))))
as_tibble(coral_health_tbl)
# Out:
#     coral              is_diseased
# 1   Montipora capitata is_healthy
# 2   Porites lobata     is_healthy
# 3   Porites compressa  is_healthy
# 4   Montipora capitata is_healthy
# 5   Montipora capitata is_healthy
# 6   Montipora capitata is_healthy
# 7   Montipora capitata is_healthy
# 8   Porites lobata     is_healthy
# 9   Porites compressa  is_healthy
# 10  Porites compressa  is_healthy
# 11  Porites compressa  is_healthy
# 12  Montipora capitata is_healthy
# 13  Porites compressa  is_healthy
# 14  Porites compressa  is_healthy
# 15  Porites compressa  is_healthy
# 16  Porites lobata     is_healthy
# 17  Montipora capitata is_healthy
# 18  Montipora capitata is_healthy
# 19  Porites lobata     is_healthy
# 20  Porites lobata     is_healthy
# 21  Porites lobata     is_healthy
# 22  Montipora capitata is_healthy
# 23  Porites lobata     is_healthy
# 24  Montipora capitata is_healthy
# 25  Porites lobata     is_healthy
# 26  Porites lobata     is_healthy
# 27  Montipora capitata is_healthy
# 28  Montipora capitata is_healthy
# 29  Porites compressa  is_healthy
# 30  Porites compressa  is_healthy
# ... ...                ...
# 71  Porites compressa  is_healthy
# 72  Porites lobata     is_diseased
# 73  Montipora capitata is_healthy
# 74  Porites compressa  is_diseased
# 75  Montipora capitata is_healthy
# 76  Montipora capitata is_healthy
# 77  Porites compressa  is_healthy
# 78  Montipora capitata is_healthy
# 79  Porites lobata     is_diseased
# 80  Porites lobata     is_healthy
# 81  Porites lobata     is_healthy
# 82  Porites compressa  is_healthy
# 83  Montipora capitata is_healthy
# 84  Porites compressa  is_diseased
# 85  Porites lobata     is_diseased
# 86  Montipora capitata is_healthy
# 87  Porites lobata     is_healthy
# 88  Porites lobata     is_healthy
# 89  Porites lobata     is_healthy
# 90  Porites compressa  is_healthy
# 91  Montipora capitata is_healthy
# 92  Porites lobata     is_healthy
# 93  Montipora capitata is_healthy
# 94  Porites compressa  is_healthy
# 95  Porites compressa  is_healthy
# 96  Porites compressa  is_healthy
# 97  Montipora capitata is_healthy
# 98  Porites lobata     is_healthy
# 99  Porites compressa  is_healthy
# 100 Montipora capitata is_diseased

# %% [markdown]
# ### Q4
#
# * The function `rnorm` is used to sample (i.e., produce) random values from a normal distribution. The syntax of the function is as follows:
# ```
# rnorm(n, mu, sd)
# ```
# where n is the number of samples to generate, mu is the mean of the distribution and `sd` is the standard deviation.
#
# Essentially what the function does is generate `n` random values from a normal distribution that is centered around the mean `mu` and has the standard deviation defined by the parameter `sd`. If you do not understand what this statement means, you should not worry as we will cover it in greater detail in the next section. However, you must know that this function generates n random values that are in some way close to the provided mean (`mu`) you provided.
#
# Use the cell below to experiment with the function `rnorm`. E.g.: try to generate 5 values from the distribution with a mean 10 and a standard deviation 1.

# %%
# Write your code here
# use extra cells if needed
rnorm(5,10,1)
# Out:
# [1] 10.510931  9.272342 10.516475 10.255659 11.700342

# %% [markdown]
# ### Q5
# * Create a new column in `coral_health_tbl` called `coral_cover`. This column represents coral cover values for the corals observed in your tibble
# * For the healthy coral (`is_diseased == FALSE`), sample the cover values from a normal with a mean of 9 and standard deviation of 2
# * For the diseased corals (`health_status = TRUE`), sample the cover values from a normal with mean 1 and std of 3
# * Note that this is a perfect scenario for using `mapply`

# %%
# Write your code here
# use extra cells if needed
generate_cover = function(x){
    if (x == TRUE){
        rnorm(1, mean=1, sd=3)
    }else{
        rnorm(1, mean=9, sd=2)
    }
}
coral_cover <- mapply(generate_cover,coral_health_tbl$is_diseased)
new_coral_health_tbl <- cbind(coral_health_tbl,coral_cover)
as_tibble(new_coral_health_tbl)
# Out:
#     coral              is_diseased coral_cover
# 1   Montipora capitata is_healthy   9.265568
# 2   Porites lobata     is_healthy   7.666517
# 3   Porites compressa  is_healthy   8.309885
# 4   Montipora capitata is_healthy   8.919032
# 5   Montipora capitata is_healthy   4.899576
# 6   Montipora capitata is_healthy   7.556840
# 7   Montipora capitata is_healthy  10.138133
# 8   Porites lobata     is_healthy   6.843060
# 9   Porites compressa  is_healthy   9.524462
# 10  Porites compressa  is_healthy   8.947661
# 11  Porites compressa  is_healthy   8.895323
# 12  Montipora capitata is_healthy   9.018439
# 13  Porites compressa  is_healthy   7.893010
# 14  Porites compressa  is_healthy   8.628959
# 15  Porites compressa  is_healthy   8.294436
# 16  Porites lobata     is_healthy  11.732977
# 17  Montipora capitata is_healthy  11.787419
# 18  Montipora capitata is_healthy   6.478913
# 19  Porites lobata     is_healthy   9.235608
# 20  Porites lobata     is_healthy   8.462756
# 21  Porites lobata     is_healthy  10.049629
# 22  Montipora capitata is_healthy   8.285896
# 23  Porites lobata     is_healthy   8.526901
# 24  Montipora capitata is_healthy   5.941576
# 25  Porites lobata     is_healthy   8.992928
# 26  Porites lobata     is_healthy   8.857653
# 27  Montipora capitata is_healthy   7.718247
# 28  Montipora capitata is_healthy   6.747524
# 29  Porites compressa  is_healthy  10.506251
# 30  Porites compressa  is_healthy   8.106651
# ... ...                ...         ...
# 71  Porites compressa  is_healthy   6.504781
# 72  Porites lobata     is_diseased  9.290638
# 73  Montipora capitata is_healthy  10.064641
# 74  Porites compressa  is_diseased 11.413556
# 75  Montipora capitata is_healthy  11.054299
# 76  Montipora capitata is_healthy  11.088608
# 77  Porites compressa  is_healthy   8.823828
# 78  Montipora capitata is_healthy   8.337789
# 79  Porites lobata     is_diseased 11.064360
# 80  Porites lobata     is_healthy   7.114205
# 81  Porites lobata     is_healthy   7.890557
# 82  Porites compressa  is_healthy   8.216659
# 83  Montipora capitata is_healthy   9.488791
# 84  Porites compressa  is_diseased  7.051638
# 85  Porites lobata     is_diseased  7.391477
# 86  Montipora capitata is_healthy   6.322894
# 87  Porites lobata     is_healthy   8.003710
# 88  Porites lobata     is_healthy  13.374620
# 89  Porites lobata     is_healthy   8.788438
# 90  Porites compressa  is_healthy   8.935376
# 91  Montipora capitata is_healthy   3.959890
# 92  Porites lobata     is_healthy  10.106333
# 93  Montipora capitata is_healthy   9.011634
# 94  Porites compressa  is_healthy   9.603534
# 95  Porites compressa  is_healthy   9.955334
# 96  Porites compressa  is_healthy   8.397941
# 97  Montipora capitata is_healthy   8.172760
# 98  Porites lobata     is_healthy   8.089492
# 99  Porites compressa  is_healthy   6.875355
# 100 Montipora capitata is_diseased  9.710091

# %% [markdown]
# ### Q6
#
# * Add another column called `binary_health_status`.
#  * set the column to 0 if `is_diseased == FALSE`
#  * set the column to 1 if `is_diseased == TRUE`
#
# * A trick here is to remember that:
#   1. Corecing (converting) a logical can be done with `as.integer()`
#   2. `as.integer(TRUE)` returns 1
#   3. `as.integer(FALSE)` returns 0

# %%
binary <- function(x){
if(x == TRUE) {
    as.integer(TRUE)
}else{
    as.integer(FALSE)
}
}

binary_health_status <- mapply(binary,new_coral_health_tbl$is_diseased)
new_binary_health_status_tbl <- cbind(new_coral_health_tbl,binary_health_status)
as_tibble(new_binary_health_status_tbl)
# Out:
#     coral              is_diseased coral_cover binary_health_status
# 1   Montipora capitata is_healthy   9.265568   0
# 2   Porites lobata     is_healthy   7.666517   0
# 3   Porites compressa  is_healthy   8.309885   0
# 4   Montipora capitata is_healthy   8.919032   0
# 5   Montipora capitata is_healthy   4.899576   0
# 6   Montipora capitata is_healthy   7.556840   0
# 7   Montipora capitata is_healthy  10.138133   0
# 8   Porites lobata     is_healthy   6.843060   0
# 9   Porites compressa  is_healthy   9.524462   0
# 10  Porites compressa  is_healthy   8.947661   0
# 11  Porites compressa  is_healthy   8.895323   0
# 12  Montipora capitata is_healthy   9.018439   0
# 13  Porites compressa  is_healthy   7.893010   0
# 14  Porites compressa  is_healthy   8.628959   0
# 15  Porites compressa  is_healthy   8.294436   0
# 16  Porites lobata     is_healthy  11.732977   0
# 17  Montipora capitata is_healthy  11.787419   0
# 18  Montipora capitata is_healthy   6.478913   0
# 19  Porites lobata     is_healthy   9.235608   0
# 20  Porites lobata     is_healthy   8.462756   0
# 21  Porites lobata     is_healthy  10.049629   0
# 22  Montipora capitata is_healthy   8.285896   0
# 23  Porites lobata     is_healthy   8.526901   0
# 24  Montipora capitata is_healthy   5.941576   0
# 25  Porites lobata     is_healthy   8.992928   0
# 26  Porites lobata     is_healthy   8.857653   0
# 27  Montipora capitata is_healthy   7.718247   0
# 28  Montipora capitata is_healthy   6.747524   0
# 29  Porites compressa  is_healthy  10.506251   0
# 30  Porites compressa  is_healthy   8.106651   0
# ... ...                ...         ...         ...
# 71  Porites compressa  is_healthy   6.504781   0
# 72  Porites lobata     is_diseased  9.290638   0
# 73  Montipora capitata is_healthy  10.064641   0
# 74  Porites compressa  is_diseased 11.413556   0
# 75  Montipora capitata is_healthy  11.054299   0
# 76  Montipora capitata is_healthy  11.088608   0
# 77  Porites compressa  is_healthy   8.823828   0
# 78  Montipora capitata is_healthy   8.337789   0
# 79  Porites lobata     is_diseased 11.064360   0
# 80  Porites lobata     is_healthy   7.114205   0
# 81  Porites lobata     is_healthy   7.890557   0
# 82  Porites compressa  is_healthy   8.216659   0
# 83  Montipora capitata is_healthy   9.488791   0
# 84  Porites compressa  is_diseased  7.051638   0
# 85  Porites lobata     is_diseased  7.391477   0
# 86  Montipora capitata is_healthy   6.322894   0
# 87  Porites lobata     is_healthy   8.003710   0
# 88  Porites lobata     is_healthy  13.374620   0
# 89  Porites lobata     is_healthy   8.788438   0
# 90  Porites compressa  is_healthy   8.935376   0
# 91  Montipora capitata is_healthy   3.959890   0
# 92  Porites lobata     is_healthy  10.106333   0
# 93  Montipora capitata is_healthy   9.011634   0
# 94  Porites compressa  is_healthy   9.603534   0
# 95  Porites compressa  is_healthy   9.955334   0
# 96  Porites compressa  is_healthy   8.397941   0
# 97  Montipora capitata is_healthy   8.172760   0
# 98  Porites lobata     is_healthy   8.089492   0
# 99  Porites compressa  is_healthy   6.875355   0
# 100 Montipora capitata is_diseased  9.710091   0

# %% [markdown]
# ### Q7
#
# * Plot the distribution of `coral_cover` for healthy versus diseased corals
# * Note that I am using the histogram `geom`
#   * Histograms need only an `x`-axis because the `y` is typically computed as the number of items occurring in a bin of some predetermined width.
#     * However, instead of a raw count, we want a normalized count. You can normalize the count by setting `y = stat(count / sum(count))`
#   * I am coloring the bin outlines in black and filling in grey for disease and white for healthy
#   * I am using `binwidth=1'.
# * Use the `labs` function to add a title and to change the labels for the `x` and `y` axes
# * The plot should look "somewhat" like the following
# ![](https://www.dropbox.com/s/wdbdj05rd50vb0k/healthy-diseased.png?dl=1)

# %% [markdown]
# ### Q8
#
# * Use `geom_density` to mirror the information conveyed in the histogram above using density curves instead of histograms.
#   * Set the `adjust` parameter of `geom_density` to `2`
# * Change the `xlim` scale so that we can see the edges of the curves
#   * I.e., curves should not be cut off
#
# * The resulting curve will look like the following
# ![](https://www.dropbox.com/s/rs4rx0w6ur8p5wq/coral_distr_practical.png?dl=1)

# %% [markdown]
# ### Q9
#
# You have been provided with the dataset illustrated in the image below, which contains counts for 20 fish species across 5 locations. For convenience, only two species and 2 locations are illustrated here. Based on your knowledge of tidy data, how can you format the data shown in this file in a way that is considered `tidy`. Provide an image of a hand-drawn table (or tables if needed) that represents the table format. Briefly justify your answer in a 3-4 sentences.
#
#
# ![](https://www.dropbox.com/s/ucvj0gburg8at60/tidy_data.png?dl=1)

# %% [markdown]
# ### Q10 -- Challenge (Optional)
#
#
# Recall problem `8` in the airquality dataset.
#   * Remember that you can import that dataset using `data(airquality)`
# 1. Convert the `airquality` dataframe to a tibble called `airq_tbl`
# 2. Replace the missing values for Solar.R using that month's average.
#     * Example:
#         * The missing value for line 6 in `airq_tbl`should be replaced with the average for month 5.
#         * The missing value for line 97 in `airq_tbl` should be replaced with the average for month 8.
#
# * Strategy:
#   1. Compute the average values for months 5, 6, 7, 8, and 9 in a names vector called `monthly_avg_SolarR`
#       * monthly_avg_SolarR[5] should return the average for May.
#       * monthly_avg_SolarR[6] should return the average for June.
#       * etc.
#       * This is an ideal use case for `tapply` with `na.rm=TRUE` (ask me!)
#   2. for each line of airq_tbl check value of Solar.R and do:
#     * if value is not `na`, return the value
#     * if value if `na`; return avg associated with `Month`
#     * This is an ideal case for `apply`
#       * You need to write your own function (call it `fix_missing_solar_R`)
#       * Recall that the argument to that function is a complete row as a vector!
#     * test your function with the following line to make sure it's working
#     ```fix_missing_solar_R(airq_tbl[5,])```
